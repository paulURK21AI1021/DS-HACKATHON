# %% [markdown]
# ##ACTIVITY 1

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
path='drive/MyDrive/Colab Notebooks/Titanic_visu.xlsx'
import pandas as pd
df = pd.read_excel(path)
df
# Out:
#     Unnamed: 0  Survived  Pclass           Name     Sex  Age  \
# 0            0         0       3         Braund    male   22
# 1            1         1       1        Cumings  female   38
# 2            2         1       3      Heikkinen  female   26
# 3            3         1       1       Futrelle  female   35
# 4            4         0       3          Allen    male   35
# 5            5         0       3          Moran    male   43
# 6            6         0       1       McCarthy    male   54
# 7            7         0       3        Palsson    male   40
# 8            8         1       3        Johnson  female   27
# 9            9         1       2         Nasser  female   26
# 10          10         1       3      Sandstrom  female   24
# 11          11         1       1        Bonnell  female   58
# 12          12         0       3    Saundercock    male   20
# 13          13         0       3      Andersson    male   39
# 14          14         0       3        Vestrom  female   26
# 15          15         1       2        Hewlett  female   55
# 16          16         0       3           Rice    male   43
# 17          17         1       2       Williams    male   42
# 18          18         0       3  Vander Planke  female   31
# 19          19         1       3     Masselmani  female   23
# 20          20         0       2         Fynney    male   35
# 21          21         1       2        Beesley    male   34
# 22          22         1       3        McGowan  female   52
# 23          23         1       1         Sloper    male   28
# 24          24         0       3        Palsson  female   48
#
#               Ticket     Fare Embarked  Concession   New_Fare
# 0          A/5 21171  53.1000        S        16.1  61.649100
# 1           PC 17599  13.0000        C        17.5  15.275000
# 2   STON/O2. 3101282  31.2750        S        16.4  36.404100
# 3             113803  18.0000        S        17.4  21.132000
# 4             373450  16.7000        S        17.4  19.605800
# 5             330877   8.0500        Q        18.7   9.555350
# 6              17463   7.8542        S        19.5   9.385769
# 7             349909  11.1333        Q        18.0  13.137294
# 8             347742  26.5500        S        16.6  30.957300
# 9             237736  30.0708        C        16.4  35.002411
# 10           PP 9549  35.5000        S        16.3  41.286500
# 11            113783   7.2250        S        20.0   8.670000
# 12         A/5. 2151  71.2833        S        16.0  82.688628
# 13            347082  13.0000        Q        17.8  15.314000
# 14            350406  29.1250        S        16.4  33.901500
# 15            248706   7.2500        S        19.8   8.685500
# 16            382652   8.0500        Q        18.7   9.555350
# 17            244373   8.4583        S        18.3  10.006169
# 18            345763  21.0750        S        17.0  24.657750
# 19              2649  51.8625        C        16.2  60.264225
# 20            239865  16.0000        S        17.4  18.784000
# 21            248698  21.0750        S        17.2  24.699900
# 22            330923   7.9250        Q        19.2   9.446600
# 23            113788  26.0000        S        16.8  30.368000
# 24            349909   8.0292        S        19.0   9.554748

# %%
# 2. Draw a comparative bar chart for Fare and New_Fare against each person (first 15 persons
import numpy as np
import matplotlib.pyplot as plt
n=15
ind=np.arange(n)
width=0.25
xval=df['Fare'].head(15)
bar1=plt.bar(ind,xval,width,color='b')
yval=df['New_Fare'].head(15)
bar2=plt.bar(ind+width,yval,width,color='r')
plt.xlabel('Person')
plt.ylabel('Fare')
plt.legend((bar1,bar2),('Fare', 'New Fare'))
plt.xticks(ind+width,df['Name'].head(15));

# %%
# 4. Draw a stacked bar chart for Fare and New_Fare against the person (first 10 persons)
plt.bar(df['Name'].head(10),df['Fare'].head(10),color='blue')
plt.bar(df['Name'].head(10),df['New_Fare'].head(10),bottom=
        df['Fare'].head(10),color="green")
plt.xlabel('People')
# Out:
# Text(0.5, 0, 'People')

# %%
# 6. Draw the dot plot between person and age (first 15 persons)
plt.plot(df['Name'].head(15),df['Age'].head(15),linewidth=0,marker='*',color='blue')
plt.xlabel('Person')
plt.ylabel('Age');

# %%
# 8.Draw the scatter plot between Fare and New_Fare. Observe the correlation
x=df['Fare']
y=df['New_Fare']
plt.scatter(x,y,c='green')
plt.xlabel('Salary')
plt.ylabel('New_Salary');

# %%
# 10. Draw the box plot to show the statistical summary of Age column and verify with describe()
df = df.sort_values(by="Age",ascending=True)
plt.boxplot(df['Age']);
df.describe()
# Out:
#        Unnamed: 0   Survived     Pclass        Age       Fare  Concession  \
# count   25.000000  25.000000  25.000000  25.000000  25.000000   25.000000
# mean    12.000000   0.520000   2.400000  36.160000  21.903664   17.604000
# std      7.359801   0.509902   0.816497  11.130588  16.673578    1.240121
# min      0.000000   0.000000   1.000000  20.000000   7.225000   16.000000
# 25%      6.000000   0.000000   2.000000  26.000000   8.050000   16.400000
# 50%     12.000000   1.000000   3.000000  35.000000  16.700000   17.400000
# 75%     18.000000   1.000000   3.000000  43.000000  29.125000   18.700000
# max     24.000000   1.000000   3.000000  58.000000  71.283300   20.000000
#
#         New_Fare
# count  25.000000
# mean   25.599480
# std    19.273926
# min     8.670000
# 25%     9.555350
# 50%    19.605800
# 75%    33.901500
# max    82.688628

# %%
# 12. Draw the histogram plot for Concession column with bin value and PDF
plt.hist(df['Concession'],edgecolor='black',density=True,bins=12);

# %% [markdown]
# ##ACTIVITY 2

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
path = "/content/drive/MyDrive/Colab Notebooks/heart.data.csv"
heart_disease = pd.read_csv(path)
heart_disease
# Out:
# Mounted at /content/drive
#      Unnamed: 0     biking    smoking  heart.disease
# 0             1  30.801246  10.896608      11.769423
# 1             2  65.129215   2.219563       2.854081
# 2             3   1.959665  17.588331      17.177803
# 3             4  44.800196   2.802559       6.816647
# 4             5  69.428454  15.974505       4.062224
# ..          ...        ...        ...            ...
# 493         494  47.660440  27.562464      11.294392
# 494         495  45.097203  21.385620       9.616762
# 495         496   8.279743   6.423720      13.495168
# 496         497  42.345863  20.741328      10.115865
# 497         498  30.774254  23.610175      11.843556
#
# [498 rows x 4 columns]

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,:-2]
y = df.iloc[:,-2]

# %%
# a. Divide the data into training (75%) and testing set (25%)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state=1)

# %%
print(x_train)
# Out:
#      Unnamed: 0     biking
# 494         495  45.097203
# 233         234  29.224098
# 80           81  64.384893
# 46           47  20.789602
# 142         143  55.580584
# ..          ...        ...
# 255         256  73.143146
# 72           73  21.750385
# 396         397  41.443284
# 235         236  46.728488
# 37           38  29.904475
#
# [373 rows x 2 columns]

# %%
# b. Analyse the impact of smoking to the heart disease and display the intercept and regression coefficients
features = ['biking', 'smoking', 'heart.disease']
target = 'heart.disease'
X_train, X_test, y_train, y_test = train_test_split(heart_disease[features], heart_disease[target], test_size=0.25, random_state=42)
model = LinearRegression()
model.fit(heart_disease[[ 'smoking']], heart_disease[target])
print("Intercept: ", model.intercept_)
print("Regression Coefficient for smoking: ", model.coef_[0])
# Out:
# Intercept:  7.543106897173153
# Regression Coefficient for smoking:  0.17048430862795927

# %%
# c. Predict the y value (y’) for the testing set (x)
features = ['biking', 'smoking', 'heart.disease']
target = ['heart.disease']
X_train, X_test, y_train, y_test = train_test_split(heart_disease[features], heart_disease[target], test_size=0.25, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [[ 6.75601546]
#  [ 9.46602604]
#  [14.08865401]
#  [13.37742996]
#  [16.38467802]
#  [13.37980742]
#  [ 7.59179728]
#  [10.05580546]
#  [ 6.80839968]
#  [12.09848437]
#  [ 7.81638864]
#  [ 9.83547443]
#  [ 4.94609016]
#  [ 9.77538589]
#  [ 7.70739764]
#  [17.05893586]
#  [ 4.29637701]
#  [ 7.98222748]
#  [ 5.52393102]
#  [ 5.92568029]
#  [ 1.10482036]
#  [ 7.61880347]
#  [12.37369096]
#  [14.17984416]
#  [11.63207228]
#  [13.17374097]
#  [ 6.50794745]
#  [10.37232868]
#  [13.37300547]
#  [11.75315615]
#  [ 8.55785408]
#  [12.04664323]
#  [12.92167259]
#  [17.17780348]
#  [ 3.29621777]
#  [ 6.51670365]
#  [ 6.7390807 ]
#  [ 7.59016604]
#  [13.28367033]
#  [10.86552244]
#  [ 2.70846056]
#  [ 3.40208038]
#  [ 8.02740434]
#  [10.37756908]
#  [11.76942278]
#  [ 8.60827208]
#  [15.98937136]
#  [ 7.47437198]
#  [17.87769197]
#  [ 3.68936446]
#  [ 0.98753645]
#  [ 5.07228124]
#  [ 6.95950199]
#  [15.19818432]
#  [ 9.74718577]
#  [ 6.71507793]
#  [ 7.93060122]
#  [11.29439158]
#  [13.01604512]
#  [ 4.07682347]
#  [ 7.3303757 ]
#  [ 7.04062107]
#  [13.47050633]
#  [ 5.56092164]
#  [11.10563057]
#  [12.81263706]
#  [16.16479395]
#  [ 5.68568185]
#  [17.47394032]
#  [ 9.23007425]
#  [ 4.70700936]
#  [ 3.74449837]
#  [18.68979793]
#  [16.19911804]
#  [ 3.10933775]
#  [ 9.51338391]
#  [13.28152871]
#  [ 6.73577092]
#  [11.1407355 ]
#  [ 8.86792508]
#  [19.43196008]
#  [ 6.91625864]
#  [14.63576932]
#  [ 7.66534592]
#  [10.23358752]
#  [ 4.09076484]
#  [14.46601284]
#  [14.80814956]
#  [14.83034396]
#  [11.60093943]
#  [ 9.78016512]
#  [13.75798666]
#  [16.3479313 ]
#  [13.33442806]
#  [ 8.74484531]
#  [12.99647582]
#  [ 4.48099302]
#  [ 5.85827788]
#  [ 5.47890872]
#  [ 8.54909495]
#  [15.0086341 ]
#  [ 6.66207532]
#  [ 5.33403739]
#  [ 7.83138475]
#  [ 3.52297632]
#  [12.074926  ]
#  [13.64807731]
#  [13.75157748]
#  [ 9.08844485]
#  [11.29631616]
#  [ 5.41591739]
#  [10.11586515]
#  [ 4.91638345]
#  [12.88681678]
#  [ 7.25794619]
#  [ 4.68009745]
#  [ 9.32447395]
#  [12.78845054]
#  [12.5378281 ]
#  [10.97176085]
#  [ 8.34557354]
#  [16.52729331]
#  [10.7291815 ]
#  [15.00071543]
#  [ 8.31089766]]

# %%
# d. Analyse the performance metrics with the actual value (y) and predicted values (y’)
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
features = ['biking', 'smoking', 'heart.disease']
target = 'heart.disease'
X_train, X_test, y_train, y_test = train_test_split(heart_disease[features], heart_disease[target], test_size=0.25, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R-Squared:", r2)
# Out:
# Mean Squared Error: 6.249356091160855e-30
# Mean Absolute Error: 1.9788615190918792e-15
# R-Squared: 1.0
